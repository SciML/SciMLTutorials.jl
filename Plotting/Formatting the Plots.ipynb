# %% [markdown]
# # Formatting The Plots
#
# Since the plotting functionality is implemented as a recipe to Plots.jl, [all of the options open to Plots.jl can be used in our plots](https://juliaplots.github.io/supported/). Let's first get the solution to some SDE. Here I will use one of the example stochastic differential equations from DiffEqProblemLibrary. `waveSDEExample()` will give me a stochastic-periodic solution. As with all commands in DifferentialEquations.jl, I got a plot of the solution by calling `solve` on the problem, and `plot` on the solution:

# %%
using DifferentialEquations, DiffEqProblemLibrary, Plots
prob = prob_sde_wave
dt = 1//2^(3) #The initial timestepping size. It will automatically assigned if not given.
tspan = [0,1] # The timespan. This is the default if not given.
sol =solve(prob,EM(),dt=dt)
plot(sol,plot_analytic=true)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3701,363.094 39.3701,13.2835
#   "/>
# ...

# %% [markdown]
# Here I used a non-standard keyword argument, `plot_analytic`, to add the true solution to the plot (which is able to be done because the true solution is defined in `prob`). However, we can add any of the commands from the Plots.jl documentation. For example, we can change the linewidths with `w` and change the legend with the `leg` keyword:

# %%
plot(sol,plot_analytic=true,w=[3 2],leg=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3701,363.094 39.3701,13.2835
#   "/>
# ...

# %% [markdown]
# You can do all sorts of things. Have fun!
