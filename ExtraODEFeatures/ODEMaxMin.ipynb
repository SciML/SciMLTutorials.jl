# %% [markdown]
# ## Finding Maxima and Minima of DiffEq Solutions
#
# ### Setup
#
# In this tutorial we will show how to use Optim.jl to find the maxima and minima of solutions. Let's take a look at the double pendulum:

# %%
#Constants and setup
using OrdinaryDiffEq
initial = [0.01, 0.01, 0.01, 0.01]
tspan = (0.,100.)

#Define the problem
function double_pendulum_hamiltonian(t,u,udot)
    α  = u[1]
    lα = u[2]
    β  = u[3]
    lβ = u[4]
    udot .=
    [2(lα-(1+cos(β))lβ)/(3-cos(2β)),
    -2sin(α) - sin(α+β),
    2(-(1+cos(β))lα + (3+2cos(β))lβ)/(3-cos(2β)),
    -sin(α+β) - 2sin(β)*(((lα-lβ)lβ)/(3-cos(2β))) + 2sin(2β)*((lα^2 - 2(1+cos(β))lα*lβ + (3+2cos(β))lβ^2)/(3-cos(2β))^2)]
end

#Pass to solvers
poincare = ODEProblem(double_pendulum_hamiltonian, initial, tspan)
sol = solve(poincare, Tsit5())
# Out:
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation
# t: 193-element Array{Float64,1}:
#    0.0
#    0.0833258
#    0.241753
#    0.438954
#    0.679732
#    0.964763
#    1.31794
#    1.70312
#    2.06785
#    2.47178
#    2.90745
#    3.43306
#    3.88197
#    ⋮
#   94.2424
#   94.7689
#   95.3188
#   95.8457
#   96.3578
#   96.9291
#   97.4468
#   97.9625
#   98.5118
#   99.0608
#   99.5828
#  100.0
# u: 193-element Array{Array{Float64,1},1}:
#  [0.01, 0.01, 0.01, 0.01]
#  [0.00917069, 0.006669, 0.0124205, 0.00826641]
#  [0.00767328, 0.000374625, 0.0164426, 0.00463683]
#  [0.00612597, -0.00730546, 0.0199674, -0.000336506]
#  [0.0049661, -0.0163086, 0.0214407, -0.00670509]
#  [0.00479557, -0.0262381, 0.0188243, -0.0139134]
#  [0.00605469, -0.0371246, 0.0100556, -0.0210382]
#  [0.00790078, -0.046676, -0.00267353, -0.025183]
#  [0.00827652, -0.0527843, -0.0127315, -0.0252581]
#  [0.00552358, -0.0552525, -0.0168439, -0.021899]
#  [-0.00130586, -0.0518559, -0.0115573, -0.0164224]
#  [-0.0116387, -0.0390164, 0.0021334, -0.0104239]
#  [-0.0178163, -0.0218269, 0.0106648, -0.0067928]
#  ⋮
#  [-0.00464681, -0.0190306, -0.0216756, -0.00725243]
#  [-0.00900101, 0.00108857, -0.0132056, 0.00598136]
#  [-0.014474, 0.0233566, 0.00384468, 0.0151414]
#  [-0.0148868, 0.0423324, 0.0136282, 0.0180291]
#  [-0.00819054, 0.0544225, 0.00944831, 0.0177401]
#  [0.00412448, 0.0567489, -0.00515392, 0.017597]
#  [0.0130796, 0.0480772, -0.0137706, 0.0182866]
#  [0.0153161, 0.0316313, -0.00895722, 0.0171185]
#  [0.0111156, 0.00992938, 0.0072972, 0.0103535]
#  [0.00571392, -0.0117872, 0.020508, -0.00231029]
#  [0.00421143, -0.0299109, 0.0187506, -0.0156505]
#  [0.00574124, -0.0416539, 0.00741327, -0.023349]

# %% [markdown]
# In time, the solution looks like:

# %%
using Plots; gr()
plot(sol, vars=[(0,3),(0,4)], leg=false, plotdensity=10000)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3701,363.094 39.3701,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   149.921,363.094 149.921,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   260.472,363.094 260.472,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   371.024,363.094 371.024,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   481.575,363.094 481.575,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,363.094 592.126,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,316.262 583.835,316.262
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,252.22 583.835,252.22
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,188.178 583.835,188.178
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,124.136 583.835,124.136
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614
# ### Local Optimization

# %% [markdown]
# Let's fine out what some of the local maxima and minima are. Optim.jl can be used to minimize functions, and the solution type has a continuous interpolation which can be used. Let's look for the local optima for the 4th variable around `t=20`. Thus our optimization function is:

# %%
f = (t) -> sol(t,idxs=4)
# Out:
# (::#45) (generic function with 1 method)

# %% [markdown]
# `first(t)` is the same as `t[1]` which transforms the array of size 1 into a number. `idxs=4` is the same as `sol(first(t))[4]` but does the calculation without a temporary array and thus is faster. To find a local minima, we can simply call Optim on this function. Let's find a local minimum:

# %%
using Optim
opt = optimize(f,18.0,22.0)
# Out:
# Results of Optimization Algorithm
#  * Algorithm: Brent's Method
#  * Search Interval: [18.000000, 22.000000]
#  * Minimizer: 1.863213e+01
#  * Minimum: -2.793164e-02
#  * Iterations: 11
#  * Convergence: max(|x - x_upper|, |x - x_lower|) <= 2*(1.5e-08*|x|+2.2e-16): true
#  * Objective Function Calls: 12

# %% [markdown]
# From this printout we see that the minimum is at `t=18.63` and the value is `-2.79e-2`. We can get these in code-form via:

# %%
println(opt.minimizer)
println(opt.minimum)
# Out:
# 18.632126799598506
# -0.027931635264245688

# %% [markdown]
# To get the maximum, we just minimize the negative of the function:

# %%
f = (t) -> -sol(first(t),idxs=4)
opt2 = optimize(f,0.0,22.0)
# Out:
# Results of Optimization Algorithm
#  * Algorithm: Brent's Method
#  * Search Interval: [0.000000, 22.000000]
#  * Minimizer: 1.399975e+01
#  * Minimum: -2.269411e-02
#  * Iterations: 13
#  * Convergence: max(|x - x_upper|, |x - x_lower|) <= 2*(1.5e-08*|x|+2.2e-16): true
#  * Objective Function Calls: 14

# %% [markdown]
# Let's add the maxima and minima to the plots:

# %%
plot(sol, vars=(0,4), plotdensity=10000)
scatter!([opt.minimizer],[opt.minimum],label="Local Min")
scatter!([opt2.minimizer],[-opt2.minimum],label="Local Max")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.0141,363.094 55.0141,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   315.748,363.094 315.748,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   576.482,363.094 576.482,13.2835
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,309.013 583.835,309.013
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,248.596 583.835,248.596
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,188.179 583.835,188.179
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,127.762 583.835,127.762
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,67.3449 583.835,67.3449
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 592.126,368.504
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.0141,368.504 55.0141,363.094
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.748,368.504 315.748,363.094
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   576.482,368.504 576.482,363.094
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,309.013 47.6614,309.013
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,248.596 47.6614,248.596
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,188.179 47.6614,188.179
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,127.762 47.6614,127.762
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,67.3449 47.6614,67.3449
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.0141, 382.304)" x="55.0141" y="382.304">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.748, 382.304)" x="315.748" y="382.304">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 576.482, 382.304)" x="576.482" y="382.304">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 313.513)" x="33.3701" y="313.513">-0.02</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 253.096)" x="33.3701" y="253.096">-0.01</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 192.679)" x="33.3701" y="192.679">0.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 132.262)" x="33.3701" y="132.262">0.01</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 71.8449)" x="33.3701" y="71.8449">0.02</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.748, 397.6)" x="315.748" y="397.6">t</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:3; stroke-opacity:1; fill:none" points="
#   55.0141,127.762 55.0663,128.976 55.1184,130.202 55.1706,131.441 55.2227,132.69 55.2749,133.952 55.327,135.224 55.3792,136.508 55.4313,137.804 55.4835,139.11
#   55.5356,140.427 55.5878,141.755 55.6399,143.093 55.6921,144.442 55.7442,145.8 55.7964,147.169 55.8485,148.548 55.9007,149.937 55.9528,151.335 56.005,152.742
#   56.0572,154.159 56.1093,155.584 56.1615,157.019 56.2136,158.462 56.2658,159.913 56.3179,161.372 56.3701,162.84 56.4222,164.315 56.4744,165.798 56.5265,167.289
#   56.5787,168.786 56.6308,170.291 56.683,171.802 56.7351,173.32 56.7873,174.844 56.8394,176.374 56.8916,177.911 56.9437,179.452 56.9959,181 57.048,182.552
#   57.1002,184.109 57.1523,185.671 57.2045,187.238 57.2566,188.809 57.3088,190.384 57.361,191.963 57.4131,193.545 57.4653,195.13 57.5174,196.719 57.5696,198.31
#   57.6217,199.904 57.6739,201.5 57.726,203.099 57.7782,204.699 57.8303,206.3 57.8825,207.903 57.9346,209.507 57.9868,211.112 58.0389,212.717 58.0911,214.323
#   58.1432,215.928 58.1954,217.534 58.2475,219.138 58.2997,220.743 58.3518,222.346 58.404,223.947 58.4561,225.548 58.5083,227.146 58.5604,228.743 58.6126,230.337
#   58.6648,231.928 58.7169,233.517 58.7691,235.103 58.8212,236.685 58.8734,238.264 58.9255,239.839 58.9777,241.41 59.0298,242.976 59.082,244.538 59.1341,246.094
#   59.1863,247.646 59.2384,249.193 59.2906,250.733 59.3427,252.268 59.3949,253.797 59.447,255.319 59.4992,256.834 59.5513,258.343 59.6035,259.845 59.6556,261.339
#   59.7078,262.826 59.7599,264.305 59.8121,265.775 59.8642,267.238 59.9164,268.691 59.9686,270.136 60.0207,271.572 60.0729,272.999 60.125,274.416 60.1772,275.824
#   60.2293,277.222 60.2815,278.609 60.3336,279.986 60.3858,281.353 60.4379,282.708 60.4901,284.053 60.5422,285.387 60.5944,286.709 60.6465,288.019 60.6987,289.317
#   60.7508,290.604 60.803,291.878 60.8551,293.14 60.9073,294.389 60.9594,295.626 61.0116,296.849 61.0637,298.059 61.1159,299.256 61.168,300.439 61.2202,301.609
#   61.2724,302.765 61.3245,303.907 61.3767,305.034 61.4288,306.148 61.481,307.246 61.5331,308.331 61.5853,

# %% [markdown]
# Brent's method will locally minimize over the full interval. If we instead want a local maxima nearest to a point, we can use `BFGS()`. In this case, we need to optimize a vector `[t]`, and thus dereference it to a number using `first(t)`.

# %%
f = (t) -> -sol(first(t),idxs=4)
opt = optimize(f,[20.0],BFGS())
# Out:
# Results of Optimization Algorithm
#  * Algorithm: BFGS
#  * Starting Point: [20.0]
#  * Minimizer: [23.297607288713078]
#  * Minimum: -2.588588e-02
#  * Iterations: 4
#  * Convergence: true
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 1.11e-04
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = NaN
#    * |g(x)| < 1.0e-08: true
#      |g(x)| = 8.42e-12
#    * stopped by an increasing objective: false
#    * Reached Maximum Number of Iterations: false
#  * Objective Calls: 16
#  * Gradient Calls: 16

# %% [markdown]
# ### Global Optimization
#
# If we instead want to find global maxima and minima, we need to look somewhere else. For this there are many choices. A pure Julia option is BlackBoxOptim.jl, but I will use NLopt.jl. Following the NLopt.jl tutorial but replacing their function with out own:

# %%
using NLopt, ForwardDiff

count = 0 # keep track of # function evaluations

function g(t::Vector, grad::Vector)
  if length(grad) > 0 
    #use ForwardDiff for the gradients
    grad[1] = ForwardDiff.derivative((t)->sol(first(t),idxs=4),t)
  end 
  sol(first(t),idxs=4)
end
opt = Opt(:GN_ORIG_DIRECT_L, 1)
lower_bounds!(opt, [0.0])
upper_bounds!(opt, [40.0])
xtol_rel!(opt,1e-8)
min_objective!(opt, g)
(minf,minx,ret) = NLopt.optimize(opt,[20.0])
println(minf," ",minx," ",ret)
max_objective!(opt, g)
(maxf,maxx,ret) = NLopt.optimize(opt,[20.0])
println(maxf," ",maxx," ",ret)
# Out:
# -0.027931635264245632 [18.6321] XTOL_REACHED
# 0.02796857193304552 [6.5537] XTOL_REACHED

# %%
plot(sol, vars=(0,4), plotdensity=10000)
scatter!([minx],[minf],label="Global Min")
scatter!([maxx],[maxf],label="Global Max")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701